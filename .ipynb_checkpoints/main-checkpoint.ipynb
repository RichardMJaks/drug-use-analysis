# %% [markdown]
# Exploring the Link Between Personality Traits and Substance Use

# %% [markdown]
# Importing both necessary and custom modules

# %%
import sys
import pandas as pd
import plotnine as pn
import sklearn as sk
import numpy as np
import data_analysis
import data_reading

# %% [markdown]
# Read in the data

# %%
data = data_reading.read_data("data/drug_consumption.csv")
human_readable_data = data_reading.convert_data(data)
human_readable_data = data_reading.convert_drug_usage_classifiers(human_readable_data)
human_readable_data
# Out:
#         ID    Age  Gender                            Education  \
# 0        1  35-44  Female     Professional Certificate/Diploma
# 1        2  25-34    Male                     Doctorate Degree
# 2        3  35-44    Male     Professional Certificate/Diploma
# 3        4  18-24  Female                      Master's Degree
# 4        5  35-44  Female                     Doctorate Degree
# ...    ...    ...     ...                                  ...
# 1880  1884  18-24  Female  Some College, No Certificate/Degree
# 1881  1885  18-24    Male  Some College, No Certificate/Degree
# 1882  1886  25-34  Female                    University Degree
# 1883  1887  18-24  Female  Some College, No Certificate/Degree
# 1884  1888  18-24    Male  Some College, No Certificate/Degree
#
#                   Country          Ethnicity  Nscore  Escore  Oscore  Ascore  \
# 0                      UK  Mixed-White/Asian    39.0    36.0    42.0    37.0
# 1                      UK              White    29.0    52.0    55.0    48.0
# 2                      UK              White    31.0    45.0    40.0    32.0
# 3                      UK              White    34.0    34.0    46.0    47.0
# 4                      UK              White    43.0    28.0    43.0    41.0
# ...                   ...                ...     ...     ...     ...     ...
# 1880                  USA              White    25.0    51.0    57.0    48.0
# 1881                  USA              White    33.0    51.0    50.0    48.0
# 1882                  USA              White    47.0    30.0    37.0    31.0
# 1883                  USA              White    45.0    26.0    48.0    32.0
# 1884  Republic of Ireland              White    31.0    53.0    56.0    50.0
#
#       ...                 Ecstasy      Heroin             Ketamine  \
# 0     ...              Never Used  Never Used           Never Used
# 1     ...      Used in Last Month  Never Used  Used in Last Decade
# 2     ...              Never Used  Never Used           Never Used
# 3     ...              Never Used  Never Used  Used in Last Decade
# 4     ...  Used over a Decade Ago  Never Used           Never Used
# ...   ...                     ...         ...                  ...
# 1880  ...              Never Used  Never Used           Never Used
# 1881  ...     Used in Last Decade  Never Used           Never Used
# 1882  ...      Used in Last Month  Never Used  Used in Last Decade
# 1883  ...       Used in Last Year  Never Used           Never Used
# 1884  ...       Used in Last Year  Never Used           Never Used
#
#                       Legalh                  LSD                Meth  \
# 0                 Never Used           Never Used          Never Used
# 1                 Never Used  Used in Last Decade   Used in Last Year
# 2                 Never Used           Never Used          Never Used
# 3                 Never Used           Never Used          Never Used
# 4     Used over a Decade Ago           Never Used          Never Used
# ...                      ...                  ...                 ...
# 1880       Used in Last Year    Used in Last Year          Never Used
# 1881       Used in Last Year    Used in Last Week  Used in Last Month
# 1882              Never Used  Used in Last Decade          Never Used
# 1883       Used in Last Year    Used in Last Year          Never Used
# 1884       Used in Last Year    Used in Last Year          Never Used
#
#                    Mushrooms             Nicotine       Semer  \
# 0                 Never Used  Used in Last Decade  Never Used
# 1                 Never Used   Used in Last Month  Never Used
# 2     Used over a Decade Ago           Never Used  Never Used
# 3                 Never Used  Used in Last Decade  Never Used
# 4        Used in Last Decade  Used in Last Decade  Never Used
# ...                      ...                  ...         ...
# 1880              Never Used           Never Used  Never Used
# 1881      Used in Last Month    Used in Last Week  Never Used
# 1882     Used in Last Decade     Used in Last Day  Never Used
# 1883       Used in Last Year   Used in Last Month  Never Used
# 1884       Used in Last Year     Used in Last Day  Never Used
#
#                       VSA
# 0              Never Used
# 1              Never Used
# 2              Never Used
# 3              Never Used
# 4              Never Used
# ...                   ...
# 1880    Used in Last Week
# 1881           Never Used
# 1882           Never Used
# 1883           Never Used
# 1884  Used in Last Decade
#
# [1885 rows x 32 columns]

# %% [markdown]
# Make a DataFrame useful for categorizing drugs

# %%
# Bring data to a shape possible to be shown as a plot
drug_usage = data_analysis.get_columns_unique_value_counts(data[data_reading.DRUG_TYPES])
drug_usage = drug_usage.transpose().reset_index(names="Drug")
drug_usage = drug_usage.melt(id_vars="Drug", var_name="Usage", value_name="Amount")

# Replace NaN amounts with 0-s
drug_usage = drug_usage.fillna(0)

drug_usage
# Out:
#           Drug Usage  Amount
# 0      Alcohol   CL0    34.0
# 1       Amphet   CL0   976.0
# 2         Amyl   CL0  1305.0
# 3       Benzos   CL0  1000.0
# 4         Caff   CL0    27.0
# ..         ...   ...     ...
# 128       Meth   CL6    73.0
# 129  Mushrooms   CL6     4.0
# 130   Nicotine   CL6   610.0
# 131      Semer   CL6     0.0
# 132        VSA   CL6     7.0
#
# [133 rows x 3 columns]

# %%
(
    pn.ggplot(drug_usage, pn.aes("Usage", "Amount", fill="Drug")) 
    + pn.geom_col(fill="#0C475B") 
    + pn.facet_wrap("Drug")
    + pn.theme(figure_size=(12, 6))
)

# %%
drug_users = drug_usage[drug_usage["Usage"] != "CL0"]
drug_users = drug_users.groupby(["Drug"], as_index=False)["Amount"].sum()
drug_users["Amount"] = drug_users["Amount"].astype(int)

# Sort values
drug_users = drug_users.assign(
    Drug=pd.Categorical(drug_users["Drug"], categories=drug_users.sort_values("Amount", ascending=False)["Drug"])
)

drug_users
# Out:
#          Drug  Amount
# 0     Alcohol    1851
# 1      Amphet     909
# 2        Amyl     580
# 3      Benzos     885
# 4        Caff    1858
# 5    Cannabis    1472
# 6        Choc    1853
# 7        Coke     847
# 8       Crack     258
# 9     Ecstasy     864
# 10     Heroin     280
# 11   Ketamine     395
# 12        LSD     816
# 13     Legalh     791
# 14       Meth     456
# 15  Mushrooms     903
# 16   Nicotine    1457
# 17      Semer       8
# 18        VSA     430

# %%
(
    pn.ggplot(drug_users, pn.aes("Drug", "Amount"))
    + pn.geom_col(fill="#ffce47")
    + pn.geom_text(pn.aes(label = "Amount"), size=10, va="bottom")
    + pn.labs(y="Amount")
    + pn.theme(figure_size=(12, 6), axis_text_x=pn.element_text(rotation=45, hjust=1))
)

# %% [markdown]
# Visualize the distribution of demographics

# %%
countries = human_readable_data.groupby("Country")["Country"].size().rename("Count").reset_index()

# %%
(
    pn.ggplot(countries, pn.aes("Country", "Count"))
    + pn.geom_col(fill="#ffce47")
    + pn.theme(figure_size=(12, 6), axis_text_x=pn.element_text(rotation=45, hjust=1))
)

# %% [markdown]
# Filter out data from countries other than UK and USA, due to lack of data (too few samples). It is to reduce the amount of change due to cultural and regional differences.

# %%
human_readable_data = human_readable_data[human_readable_data["Country"].isin(["USA", "UK"])]
data = data[data["Country"].isin([0.96082, -0.57009])]
human_readable_data
# Out:
#         ID    Age  Gender                            Education Country  \
# 0        1  35-44  Female     Professional Certificate/Diploma      UK
# 1        2  25-34    Male                     Doctorate Degree      UK
# 2        3  35-44    Male     Professional Certificate/Diploma      UK
# 3        4  18-24  Female                      Master's Degree      UK
# 4        5  35-44  Female                     Doctorate Degree      UK
# ...    ...    ...     ...                                  ...     ...
# 1877  1881  18-24    Male              Left School at 17 years     USA
# 1880  1884  18-24  Female  Some College, No Certificate/Degree     USA
# 1881  1885  18-24    Male  Some College, No Certificate/Degree     USA
# 1882  1886  25-34  Female                    University Degree     USA
# 1883  1887  18-24  Female  Some College, No Certificate/Degree     USA
#
#               Ethnicity  Nscore  Escore  Oscore  Ascore  ...  \
# 0     Mixed-White/Asian    39.0    36.0    42.0    37.0  ...
# 1                 White    29.0    52.0    55.0    48.0  ...
# 2                 White    31.0    45.0    40.0    32.0  ...
# 3                 White    34.0    34.0    46.0    47.0  ...
# 4                 White    43.0    28.0    43.0    41.0  ...
# ...                 ...     ...     ...     ...     ...  ...
# 1877              White    50.0    26.0    42.0    31.0  ...
# 1880              White    25.0    51.0    57.0    48.0  ...
# 1881              White    33.0    51.0    50.0    48.0  ...
# 1882              White    47.0    30.0    37.0    31.0  ...
# 1883              White    45.0    26.0    48.0    32.0  ...
#
#                      Ecstasy             Heroin             Ketamine  \
# 0                 Never Used         Never Used           Never Used
# 1         Used in Last Month         Never Used  Used in Last Decade
# 2                 Never Used         Never Used           Never Used
# 3                 Never Used         Never Used  Used in Last Decade
# 4     Used over a Decade Ago         Never Used           Never Used
# ...                      ...                ...                  ...
# 1877     Used in Last Decade  Used in Last Week           Never Used
# 1880              Never Used         Never Used           Never Used
# 1881     Used in Last Decade         Never Used           Never Used
# 1882      Used in Last Month         Never Used  Used in Last Decade
# 1883       Used in Last Year         Never Used           Never Used
#
#                       Legalh                  LSD                Meth  \
# 0                 Never Used           Never Used          Never Used
# 1                 Never Used  Used in Last Decade   Used in Last Year
# 2                 Never Used           Never Used          Never Used
# 3                 Never Used           Never Used          Never Used
# 4     Used over a Decade Ago           Never Used          Never Used
# ...                      ...                  ...                 ...
# 1877     Used in Last Decade           Never Used    Used in Last Day
# 1880       Used in Last Year    Used in Last Year          Never Used
# 1881       Used in Last Year    Used in Last Week  Used in Last Month
# 1882              Never Used  Used in Last Decade          Never Used
# 1883       Used in Last Year    Used in Last Year          Never Used
#
#                    Mushrooms             Nicotine       Semer  \
# 0                 Never Used  Used in Last Decade  Never Used
# 1                 Never Used   Used in Last Month  Never Used
# 2     Used over a Decade Ago           Never Used  Never Used
# 3                 Never Used  Used in Last Decade  Never Used
# 4        Used in Last Decade  Used in Last Decade  Never Used
# ...                      ...                  ...         ...
# 1877              Never Used     Used in Last Day  Never Used
# 1880              Never Used           Never Used  Never Used
# 1881      Used in Last Month    Used in Last Week  Never Used
# 1882     Used in Last Decade     Used in Last Day  Never Used
# 1883       Used in Last Year   Used in Last Month  Never Used
#
#                       VSA
# 0              Never Used
# 1              Never Used
# 2              Never Used
# 3              Never Used
# 4              Never Used
# ...                   ...
# 1877  Used in Last Decade
# 1880    Used in Last Week
# 1881           Never Used
# 1882           Never Used
# 1883           Never Used
#
# [1601 rows x 32 columns]

# %% [markdown]
# Get drug usage and personality trait dataframe

# %%
columns = data_reading.PERSONALITY_TRAITS + data_reading.DRUG_TYPES
drug_personality_grouping = human_readable_data[columns]
drug_personality_grouping
# Out:
#       Nscore  Ascore  Oscore  Escore  Cscore  Impulsive    SS  \
# 0       39.0    37.0    42.0    36.0    42.0        4.0   3.0
# 1       29.0    48.0    55.0    52.0    41.0        3.0   6.0
# 2       31.0    32.0    40.0    45.0    34.0        2.0   8.0
# 3       34.0    47.0    46.0    34.0    46.0        2.0   3.0
# 4       43.0    41.0    43.0    28.0    50.0        4.0   6.0
# ...      ...     ...     ...     ...     ...        ...   ...
# 1877    50.0    31.0    42.0    26.0    46.0        4.0  10.0
# 1880    25.0    48.0    57.0    51.0    33.0        7.0  11.0
# 1881    33.0    48.0    50.0    51.0    30.0        7.0   9.0
# 1882    47.0    31.0    37.0    30.0    31.0        6.0   5.0
# 1883    45.0    32.0    48.0    26.0    22.0        8.0  10.0
#
#                  Alcohol                  Amphet                    Amyl  ...  \
# 0      Used in Last Week     Used in Last Decade              Never Used  ...
# 1      Used in Last Week     Used in Last Decade     Used in Last Decade  ...
# 2       Used in Last Day              Never Used              Never Used  ...
# 3     Used in Last Month              Never Used              Never Used  ...
# 4     Used in Last Month  Used over a Decade Ago  Used over a Decade Ago  ...
# ...                  ...                     ...                     ...  ...
# 1877    Used in Last Day     Used in Last Decade              Never Used  ...
# 1880   Used in Last Week              Never Used              Never Used  ...
# 1881   Used in Last Week              Never Used              Never Used  ...
# 1882  Used in Last Month        Used in Last Day       Used in Last Week  ...
# 1883   Used in Last Week              Never Used              Never Used  ...
#
#                      Ecstasy             Heroin             Ketamine  \
# 0                 Never Used         Never Used           Never Used
# 1         Used in Last Month         Never Used  Used in Last Decade
# 2                 Never Used         Never Used           Never Used
# 3                 Never Used         Never Used  Used in Last Decade
# 4     Used over a Decade Ago         Never Used           Never Used
# ...                      ...                ...                  ...
# 1877     Used in Last Decade  Used in Last Week           Never Used
# 1880              Never Used         Never Used           Never Used
# 1881     Used in Last Decade         Never Used           Never Used
# 1882      Used in Last Month         Never Used  Used in Last Decade
# 1883       Used in Last Year         Never Used           Never Used
#
#                       Legalh                  LSD                Meth  \
# 0                 Never Used           Never Used          Never Used
# 1                 Never Used  Used in Last Decade   Used in Last Year
# 2                 Never Used           Never Used          Never Used
# 3                 Never Used           Never Used          Never Used
# 4     Used over a Decade Ago           Never Used          Never Used
# ...                      ...                  ...                 ...
# 1877     Used in Last Decade           Never Used    Used in Last Day
# 1880       Used in Last Year    Used in Last Year          Never Used
# 1881       Used in Last Year    Used in Last Week  Used in Last Month
# 1882              Never Used  Used in Last Decade          Never Used
# 1883       Used in Last Year    Used in Last Year          Never Used
#
#                    Mushrooms             Nicotine       Semer  \
# 0                 Never Used  Used in Last Decade  Never Used
# 1                 Never Used   Used in Last Month  Never Used
# 2     Used over a Decade Ago           Never Used  Never Used
# 3                 Never Used  Used in Last Decade  Never Used
# 4        Used in Last Decade  Used in Last Decade  Never Used
# ...                      ...                  ...         ...
# 1877              Never Used     Used in Last Day  Never Used
# 1880              Never Used           Never Used  Never Used
# 1881      Used in Last Month    Used in Last Week  Never Used
# 1882     Used in Last Decade     Used in Last Day  Never Used
# 1883       Used in Last Year   Used in Last Month  Never Used
#
#                       VSA
# 0              Never Used
# 1              Never Used
# 2              Never Used
# 3              Never Used
# 4              Never Used
# ...                   ...
# 1877  Used in Last Decade
# 1880    Used in Last Week
# 1881           Never Used
# 1882           Never Used
# 1883           Never Used
#
# [1601 rows x 26 columns]

# %%
drug_index = pd.MultiIndex.from_product(
    [data_reading.DRUG_TYPES, data_reading.DRUG_CLASSIFIER.values()], 
    names=["Drug", "Classifier"]
)
drug_index
# Out:
# MultiIndex([('Alcohol',             'Never Used'),
#             ('Alcohol', 'Used over a Decade Ago'),
#             ('Alcohol',    'Used in Last Decade'),
#             ('Alcohol',      'Used in Last Year'),
#             ('Alcohol',     'Used in Last Month'),
#             ('Alcohol',      'Used in Last Week'),
#             ('Alcohol',       'Used in Last Day'),
#             ( 'Amphet',             'Never Used'),
#             ( 'Amphet', 'Used over a Decade Ago'),
#             ( 'Amphet',    'Used in Last Decade'),
#             ...
#             (  'Semer',     'Used in Last Month'),
#             (  'Semer',      'Used in Last Week'),
#             (  'Semer',       'Used in Last Day'),
#             (    'VSA',             'Never Used'),
#             (    'VSA', 'Used over a Decade Ago'),
#             (    'VSA',    'Used in Last Decade'),
#             (    'VSA',      'Used in Last Year'),
#             (    'VSA',     'Used in Last Month'),
#             (    'VSA',      'Used in Last Week'),
#             (    'VSA',       'Used in Last Day')],
#            names=['Drug', 'Classifier'], length=133)

# %% [markdown]
# Get all single drug users

# %%
grouped_usage = pd.DataFrame(columns=["Drug", "Classifier", "Trait", "Score"])
for drug_type in data_reading.DRUG_TYPES:
    single_drug_grouping = drug_personality_grouping[data_reading.PERSONALITY_TRAITS + [drug_type]]
    single_drug_grouping = single_drug_grouping.groupby(drug_type).mean().reset_index()
    single_drug_grouping = single_drug_grouping.rename(columns={drug_type: "Classifier"})
    single_drug_grouping["Drug"] = drug_type

    melted = single_drug_grouping.melt(
        id_vars=["Drug", "Classifier"],
        value_vars=data_reading.PERSONALITY_TRAITS,
        var_name="Trait",
        value_name="Score"
    )
    
    grouped_usage = pd.concat(
        (grouped_usage, melted)
    )

grouped_usage
# Out:
# /tmp/ipykernel_27928/323744696.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#        Drug              Classifier   Trait      Score
# 0   Alcohol              Never Used  Nscore  34.740741
# 1   Alcohol        Used in Last Day  Nscore  36.273349
# 2   Alcohol     Used in Last Decade  Nscore  38.898305
# 3   Alcohol      Used in Last Month  Nscore  36.255507
# 4   Alcohol       Used in Last Week  Nscore  35.144158
# ..      ...                     ...     ...        ...
# 44      VSA     Used in Last Decade      SS   8.429825
# 45      VSA      Used in Last Month      SS   8.500000
# 46      VSA       Used in Last Week      SS   9.900000
# 47      VSA       Used in Last Year      SS   8.220000
# 48      VSA  Used over a Decade Ago      SS   6.818182
#
# [917 rows x 4 columns]

# %%
(
    pn.ggplot(grouped_usage, pn.aes("Trait", "Score", fill="Drug")) 
    + pn.geom_col(fill="#0C475B")
    + pn.facet_grid("Drug ~ Classifier")
    + pn.theme(figure_size=(25, 25))
)
